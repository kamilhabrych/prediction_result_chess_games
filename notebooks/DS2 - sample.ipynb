# %%
import pandas as pd

# %%
df = pd.read_csv('../csv/d2_final.csv')

# %%
df.drop('Unnamed: 0', axis = 1, inplace = True)

# %%
df.head()
# Out:
#    Result  WhiteElo  BlackElo  EloDiff  Event  ECO_enc  Termination  \
# 0       1      2460      2218      242      0      200            1
# 1       1      2428      2424        4      0      483            0
# 2       1      2441      2300      141      4      106            0
# 3       2      2280      2667     -387      0      464            0
# 4       1      2557      2682     -125      0       41            0
#
#    TimeControl_enc
# 0                6
# 1                6
# 2               13
# 3                6
# 4                6

# %%
df.shape
# Out:
# (98756, 8)

# %%
df1 = df[df['Result'] == 1]
df2 = df[df['Result'] == 2]
df3 = df[df['Result'] == 3]

# %%
print(df1.shape)
print(df2.shape)
print(df3.shape)
# Out:
# (47170, 8)
# (42549, 8)
# (9037, 8)

# %%
df1 = df1.sample(n = 9037, random_state = 42)
df2 = df2.sample(n = 9037, random_state = 42)

# %%
df_sample = pd.concat([df1, df2, df3], ignore_index = True)

df_sample
# Out:
#        Result  WhiteElo  BlackElo  EloDiff  Event  ECO_enc  Termination  \
# 0           1      2669      2625       44      0      101            0
# 1           1      2516      2337      179      0      120            1
# 2           1      2468      2435       33      0      106            0
# 3           1      2404      2337       67      0       10            0
# 4           1      2295      2438     -143      0      492            0
# ...       ...       ...       ...      ...    ...      ...          ...
# 27106       3      2546      2360      186      0      250            0
# 27107       3      2425      2363       62      0      150            0
# 27108       3      2402      2358       44      0      245            0
# 27109       3      2330      2458     -128      0      107            0
# 27110       3      2484      2477        7      0       45            0
#
#        TimeControl_enc
# 0                    6
# 1                    6
# 2                    6
# ...

# %%
df_sample.to_csv('../csv/df2_sample.csv', index = False)
